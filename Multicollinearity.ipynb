# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# --- Step 1: Create a dataset ---
np.random.seed(10)
X1 = np.random.rand(100)
X2 = 2 * X1 + np.random.rand(100) * 0.1   # Highly correlated with X1
X3 = np.random.rand(100)                   # Independent feature

df = pd.DataFrame({
    'X1': X1,
    'X2': X2,
    'X3': X3
})

# --- Step 2: Correlation matrix ---
print("Correlation Matrix:")
print(df.corr(), "\n")

# --- Step 3: Calculate VIF for each variable ---
vif_data = pd.DataFrame()
vif_data["Feature"] = df.columns
vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]

print("Variance Inflation Factor (VIF):")
print(vif_data)
# Out:
# Correlation Matrix:
#           X1        X2        X3
# X1  1.000000  0.998761 -0.068272
# X2  0.998761  1.000000 -0.062566
# X3 -0.068272 -0.062566  1.000000
#
# Variance Inflation Factor (VIF):
#   Feature          VIF
# 0      X1  1303.827822
# 1      X2  1350.176206
# 2      X3     2.959544

# %% [markdown]
# The output shows which features are highly correlated with each other (X1 and X2 have high VIF) and which are independent (X3 has low VIF).
